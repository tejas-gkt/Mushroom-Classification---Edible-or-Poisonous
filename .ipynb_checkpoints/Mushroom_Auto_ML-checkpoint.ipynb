# %%
# Import necessary libraries
from pycaret.classification import *

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Data.csv')

# %%
data.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
# Setup PyCaret for classification
clf = setup(data=data, target='class', session_id=123)

# Compare different models and choose the best one
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_f8c67_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8c67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8c67_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8c67_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8c67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8c67_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f8c67_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f8c67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8c67_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8c67_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_f8c67_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Create a specific model (e.g., Random Forest)
rf_model = create_model('rf')

# Tune the Random Forest model
tuned_rf = tune_model(rf_model)

# Evaluate the tuned model
evaluate_model(tuned_rf)

# Make predictions on new data (if available)
# predictions = predict_model(tuned_rf, data=new_data)

# Finalize the model (train on the full dataset)
#final_rf_model = finalize_model(tuned_rf)

# Save the model
#save_model(final_rf_model, 'final_rf_model')

# Load the model later
#loaded_rf_model = load_model('final_rf_model')
# Out:
# <style type="text/css">
# #T_5286a_row10_col0, #T_5286a_row10_col1, #T_5286a_row10_col2, #T_5286a_row10_col3, #T_5286a_row10_col4, #T_5286a_row10_col5, #T_5286a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5286a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5286a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5286a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5286a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5286a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5286a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5286a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5286a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
